# %% [markdown]
# Mounting Google drive with colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Loading Dataset from drive **

# %%
import numpy as np
import pandas as pd

carsData = pd.read_csv('/content/drive/MyDrive/DL-Assignments/CarPrice_Assignment.csv')

# %%
carsData
# Out:
#      car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0         1          3        alfa-romero giulia  ...      21         27  13495.0
# 1         2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2         3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3         4          2               audi 100 ls  ...      24         30  13950.0
# 4         5          2                audi 100ls  ...      18         22  17450.0
# ..      ...        ...                       ...  ...     ...        ...      ...
# 200     201         -1           volvo 145e (sw)  ...      23         28  16845.0
# 201     202         -1               volvo 144ea  ...      19         25  19045.0
# 202     203         -1               volvo 244dl  ...      18         23  21485.0
# 203     204         -1                 volvo 246  ...      26         27  22470.0
# 204     205         -1               volvo 264gl  ...      19         25  22625.0
#
# [205 rows x 26 columns]

# %%
carsData.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
#Checking Which columns are object and non-object to do encoding for object types
carsData.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
#dropping carID column as it will no be considered when we predict price

carsData.drop(columns=["car_ID"], inplace=True)

# %%
#Checking null values 

carsData.isnull().any()
# Out:
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
#encoding the object type columns 

preprocessedData = pd.get_dummies(carsData , columns=['CarName','symboling','fueltype','aspiration','doornumber','carbody','drivewheel','enginelocation', 'enginetype' ,'cylindernumber' ,'fuelsystem'])

# %%
preprocessedData
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0         88.6      168.8  ...                0                0
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [205 rows x 205 columns]

# %%
#initiliazing with seed to have same data everytime 
#then splitting data into traing and testing by masking (i.e, all the values less then 0.72 will be separated from other and would give boolean array)

np.random.seed(900)
mask = np.random.rand(len(preprocessedData)) < 0.72
train_data = preprocessedData[mask]
test_data = preprocessedData[~mask]

# %%
train_data.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 205 columns]

# %%
print("trainShape" ,train_data.shape)
print("testShape" ,test_data.shape)
# Out:
# trainShape (157, 205)
# testShape (48, 205)

# %%
#separating the label from data

train_label = train_data.loc[: , "price"]
test_label = test_data.loc[: , "price"]

# %%
train_label
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 157, dtype: float64

# %%
#dropping price columns because its of no use here while traing and testing data as it will work as a label

train_data = train_data.drop(columns=["price"])
test_data = test_data.drop(columns=["price"])

# %%
train_data.columns
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        ...
#        'cylindernumber_twelve', 'cylindernumber_two', 'fuelsystem_1bbl',
#        'fuelsystem_2bbl', 'fuelsystem_4bbl', 'fuelsystem_idi',
#        'fuelsystem_mfi', 'fuelsystem_mpfi', 'fuelsystem_spdi',
#        'fuelsystem_spfi'],
#       dtype='object', length=204)

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0         88.6      168.8  ...                0                0
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [157 rows x 204 columns]

# %%
#normalizing data for the values which range is not justified and have divergent ranges

mean = train_data.iloc[:,0:13].mean(axis=0)
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
#if dataset is normalzied then label should be too

mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
test = np.array(test_data.iloc[:]).astype('float32')
train = np.array(train_data.iloc[:]).astype('float32')
test_l= np.array(test_label.astype('float32'))
train_l= np.array(train_label.astype('float32'))

# %%
#building the model by having argumented activation function by user to have multiple views

from keras import models
from keras import layers
def build_model(actFunc):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= actFunc,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= actFunc))
  model.add(layers.Dense(32, activation= actFunc))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               26240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 36,609
# Trainable params: 36,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               26240
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 36,609
# Trainable params: 36,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
#build the model using regularizer technique

from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                2050
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,199
# Trainable params: 2,199
# Non-trainable params: 0
# _________________________________________________________________

# %%
# now build for dropout model

from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                2050
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,199
# Trainable params: 2,199
# Non-trainable params: 0
# _________________________________________________________________

# %%
#k fold validation with relu
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bedfb9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bdc068c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91becb7560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bedfb320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91c2babdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bedcc200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91c530b5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bed2bd40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 118/118 [==============================] - 1s 1ms/step - loss: 0.6518 - mae: 0.5652
# Epoch 2/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.8653 - mae: 0.5967
# Epoch 3/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.8725 - mae: 0.6247
# Epoch 4/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5058 - mae: 0.4531
# Epoch 5/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4789 - mae: 0.4792
# Epoch 6/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4948 - mae: 0.4616
# Epoch 7/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4235 - mae: 0.4614
# Epoch 8/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3742 - mae: 0.4608
# Epoch 9/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5114 - mae: 0.5518
# Epoch 10/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4076 - mae: 0.4690
# Epoch 11/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3190 - mae: 0.4086
# Epoch 12/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5068 - mae: 0.4633
# Epoch 13/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2902 - mae: 0.3405
# Epoch 14/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2641 - mae: 0.3463
# Epoch 15/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3139 - mae: 0.3640
# Epoch 16/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3273 - mae: 0.3891
# Epoch 17/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3344 - mae: 0.3887
# Epoch 18/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3945 - mae: 0.3873
# Epoch 19/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4290 - mae: 0.3755
# Epoch 20/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3288 - mae: 0.3884
# Epoch 21/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2887 - mae: 0.3168
# Epoch 22/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4291 - mae: 0.4205
# Epoch 23/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1866 - mae: 0.2887
# Epoch 24/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2459 - mae: 0.3462
# Epoch 25/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2277 - mae: 0.2815
# Epoch 26/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4933 - mae: 0.4243
# Epoch 27/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.6682 - mae: 0.4275
# Epoch 28/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4296 - mae: 0.3804
# Epoch 29/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2998 - mae: 0.3075
# Epoch 30/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3048 - mae: 0.3524
# Epoch 31/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2786 - mae: 0.3481
# Epoch 32/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2102 - mae: 0.3154
# Epoch 33/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2597 - mae: 0.3675
# Epoch 34/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2346 - mae: 0.2969
# Epoch 35/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4323 - mae: 0.3649
# Epoch 36/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2825 - mae: 0.3154
# Epoch 37/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2177 - mae: 0.3435
# Epoch 38/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2232 - mae: 0.2980
# Epoch 39/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5102 - mae: 0.4012
# Epoch 40/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4381 - mae: 0.3589
# Epoch 41/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3806 - mae: 0.3527
# Epoch 42/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1658 - mae: 0.2652
# Epoch 43/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.8045 - mae: 0.4661
# Epoch 44/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2425 - mae: 0.3252
# Epoch 45/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4062 - mae: 0.3323
# Epoch 46/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2051 - mae: 0.2951
# Epoch 47/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2518 - mae: 0.3565
# Epoch 48/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2528 - mae: 0.3142
# Epoch 49/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5768 - mae: 0.4073
# Epoch 50/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5022 - mae: 0.3796
# Epoch 51/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4131 - mae: 0.3660
# Epoch 52/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1549 - mae: 0.2815
# Epoch 53/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3490 - mae: 0.3443
# Epoch 54/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2585 - mae: 0.3104
# Epoch 55/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1831 - mae: 0.2822
# Epoch 56/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3037 - mae: 0.2933
# Epoch 57/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2670 - mae: 0.3036
# Epoch 58/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3876 - mae: 0.4002
# Epoch 59/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2019 - mae: 0.2760
# Epoch 60/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2725 - mae: 0.3257
# Epoch 61/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2517 - mae: 0.2822
# Epoch 62/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2563 - mae: 0.3062
# Epoch 63/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4304 - mae: 0.3225
# Epoch 64/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2395 - mae: 0.3248
# Epoch 65/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3345 - mae: 0.3090
# Epoch 66/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2530 - mae: 0.3196
# Epoch 67/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2104 - mae: 0.2831
# Epoch 68/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1508 - mae: 0.2598
# Epoch 69/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4367 - mae: 0.3552
# Epoch 70/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2846 - mae: 0.3101
# Epoch 71/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3290 - mae: 0.3431
# Epoch 72/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1599 - mae: 0.2741
# Epoch 73/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3151 - mae: 0.3275
# Epoch 74/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2120 - mae: 0.2533
# Epoch 75/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1826 - mae: 0.2738
# Epoch 76/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1405 - mae: 0.2361
# Epoch 77/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3303 - mae: 0.3404
# Epoch 78/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2293 - mae: 0.2771
# Epoch 79/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4328 - mae: 0.3257
# Epoch 80/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3235 - mae: 0.3279
# Epoch 81/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2493 - mae: 0.3061
# Epoch 82/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4427 - mae: 0.3570
# Epoch 83/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1037 - mae: 0.2085
# Epoch 84/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1253 - mae: 0.2316
# Epoch 85/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1443 - mae: 0.2536
# Epoch 86/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3044 - mae: 0.3082
# Epoch 87/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1417 - mae: 0.2442
# Epoch 88/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3388 - mae: 0.3442
# Epoch 89/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1558 - mae: 0.2565
# Epoch 90/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1428 - mae: 0.2513
# Epoch 91/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2721 - mae: 0.2951
# Epoch 92/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2538 - mae: 0.2948
# Epoch 93/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1168 - mae: 0.2016
# Epoch 94/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3750 - mae: 0.3265
# Epoch 95/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1567 - mae: 0.2583
# Epoch 96/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1782 - mae: 0.2799
# Epoch 97/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1899 - mae: 0.2804
# Epoch 98/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1332 - mae: 0.2112
# Epoch 99/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2917 - mae: 0.3147
# Epoch 100/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1005 - mae: 0.2263
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bfd5c5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4516 - mae: 0.4714
# processing fold # 1
# Epoch 1/100
# 118/118 [==============================] - 1s 1ms/step - loss: 0.6101 - mae: 0.6281
# Epoch 2/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7328 - mae: 0.6627
# Epoch 3/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.6219 - mae: 0.5711
# Epoch 4/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7434 - mae: 0.6155
# Epoch 5/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4188 - mae: 0.4687
# Epoch 6/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4409 - mae: 0.4292
# Epoch 7/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2892 - mae: 0.4418
# Epoch 8/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2943 - mae: 0.3753
# Epoch 9/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4205 - mae: 0.4221
# Epoch 10/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.6835 - mae: 0.5103
# Epoch 11/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2949 - mae: 0.3411
# Epoch 12/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3137 - mae: 0.3382
# Epoch 13/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4404 - mae: 0.4555
# Epoch 14/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3187 - mae: 0.3718
# Epoch 15/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1932 - mae: 0.3197
# Epoch 16/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3165 - mae: 0.3584
# Epoch 17/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2369 - mae: 0.3392
# Epoch 18/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3138 - mae: 0.3992
# Epoch 19/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2577 - mae: 0.4027
# Epoch 20/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3814 - mae: 0.4098
# Epoch 21/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2752 - mae: 0.3333
# Epoch 22/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3844 - mae: 0.3807
# Epoch 23/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3740 - mae: 0.3788
# Epoch 24/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2708 - mae: 0.3542
# Epoch 25/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2619 - mae: 0.3436
# Epoch 26/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2170 - mae: 0.2941
# Epoch 27/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1693 - mae: 0.2996
# Epoch 28/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2308 - mae: 0.3085
# Epoch 29/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2621 - mae: 0.3784
# Epoch 30/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2710 - mae: 0.3812
# Epoch 31/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2124 - mae: 0.3157
# Epoch 32/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2746 - mae: 0.3509
# Epoch 33/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1681 - mae: 0.2821
# Epoch 34/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2462 - mae: 0.3567
# Epoch 35/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2929 - mae: 0.3062
# Epoch 36/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2489 - mae: 0.3833
# Epoch 37/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1566 - mae: 0.3052
# Epoch 38/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2793 - mae: 0.3383
# Epoch 39/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1349 - mae: 0.2689
# Epoch 40/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2162 - mae: 0.3043
# Epoch 41/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2970 - mae: 0.3341
# Epoch 42/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1580 - mae: 0.2570
# Epoch 43/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2511 - mae: 0.3068
# Epoch 44/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2007 - mae: 0.3085
# Epoch 45/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1637 - mae: 0.2610
# Epoch 46/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3029 - mae: 0.4060
# Epoch 47/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3426 - mae: 0.3870
# Epoch 48/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2142 - mae: 0.3246
# Epoch 49/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2110 - mae: 0.2828
# Epoch 50/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2275 - mae: 0.3264
# Epoch 51/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1604 - mae: 0.2707
# Epoch 52/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1751 - mae: 0.2922
# Epoch 53/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2777 - mae: 0.3001
# Epoch 54/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1796 - mae: 0.3027
# Epoch 55/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2088 - mae: 0.3019
# Epoch 56/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2476 - mae: 0.3262
# Epoch 57/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.0822 - mae: 0.2141
# Epoch 58/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1320 - mae: 0.2358
# Epoch 59/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1833 - mae: 0.3308
# Epoch 60/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1936 - mae: 0.2858
# Epoch 61/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3058 - mae: 0.3261
# Epoch 62/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1236 - mae: 0.2452
# Epoch 63/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2890 - mae: 0.3183
# Epoch 64/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1926 - mae: 0.2828
# Epoch 65/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2058 - mae: 0.3024
# Epoch 66/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1803 - mae: 0.3172
# Epoch 67/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2224 - mae: 0.3504
# Epoch 68/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2167 - mae: 0.2965
# Epoch 69/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2744 - mae: 0.3119
# Epoch 70/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1509 - mae: 0.2698
# Epoch 71/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2871 - mae: 0.3228
# Epoch 72/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2482 - mae: 0.3396
# Epoch 73/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2646 - mae: 0.3178
# Epoch 74/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3229 - mae: 0.3076
# Epoch 75/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1916 - mae: 0.2847
# Epoch 76/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1476 - mae: 0.2731
# Epoch 77/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2691 - mae: 0.3144
# Epoch 78/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1164 - mae: 0.2367
# Epoch 79/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1758 - mae: 0.3302
# Epoch 80/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3629 - mae: 0.3415
# Epoch 81/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2086 - mae: 0.3138
# Epoch 82/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2286 - mae: 0.3152
# Epoch 83/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3860 - mae: 0.3553
# Epoch 84/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1264 - mae: 0.2487
# Epoch 85/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1920 - mae: 0.2876
# Epoch 86/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1546 - mae: 0.2580
# Epoch 87/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2469 - mae: 0.2729
# Epoch 88/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2366 - mae: 0.2931
# Epoch 89/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1233 - mae: 0.2501
# Epoch 90/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1201 - mae: 0.2499
# Epoch 91/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3079 - mae: 0.3323
# Epoch 92/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2525 - mae: 0.2576
# Epoch 93/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3406 - mae: 0.2896
# Epoch 94/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1924 - mae: 0.2995
# Epoch 95/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1235 - mae: 0.2098
# Epoch 96/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4024 - mae: 0.3173
# Epoch 97/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1304 - mae: 0.2503
# Epoch 98/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1565 - mae: 0.2740
# Epoch 99/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2168 - mae: 0.2835
# Epoch 100/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2321 - mae: 0.3186
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91c53b3e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3948 - mae: 0.4187
# processing fold # 2
# Epoch 1/100
# 118/118 [==============================] - 1s 1ms/step - loss: 1.1982 - mae: 0.8706
# Epoch 2/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.9208 - mae: 0.6865
# Epoch 3/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.9436 - mae: 0.6409
# Epoch 4/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4454 - mae: 0.4526
# Epoch 5/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.6202 - mae: 0.5249
# Epoch 6/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2925 - mae: 0.4013
# Epoch 7/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.6983 - mae: 0.5526
# Epoch 8/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3517 - mae: 0.4219
# Epoch 9/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4072 - mae: 0.4700
# Epoch 10/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3296 - mae: 0.3961
# Epoch 11/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4401 - mae: 0.4584
# Epoch 12/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3279 - mae: 0.3801
# Epoch 13/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2145 - mae: 0.3323
# Epoch 14/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2331 - mae: 0.3486
# Epoch 15/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4372 - mae: 0.3767
# Epoch 16/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4184 - mae: 0.4529
# Epoch 17/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2941 - mae: 0.3647
# Epoch 18/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4285 - mae: 0.4384
# Epoch 19/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2842 - mae: 0.3361
# Epoch 20/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4412 - mae: 0.4241
# Epoch 21/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3632 - mae: 0.3429
# Epoch 22/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3407 - mae: 0.3963
# Epoch 23/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3399 - mae: 0.3852
# Epoch 24/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2484 - mae: 0.3226
# Epoch 25/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2730 - mae: 0.3595
# Epoch 26/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5833 - mae: 0.4696
# Epoch 27/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4070 - mae: 0.4188
# Epoch 28/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3318 - mae: 0.3265
# Epoch 29/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2739 - mae: 0.3172
# Epoch 30/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3607 - mae: 0.3771
# Epoch 31/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3702 - mae: 0.3481
# Epoch 32/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2561 - mae: 0.3699
# Epoch 33/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1517 - mae: 0.2924
# Epoch 34/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3905 - mae: 0.3350
# Epoch 35/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2964 - mae: 0.3349
# Epoch 36/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1759 - mae: 0.2979
# Epoch 37/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2003 - mae: 0.3160
# Epoch 38/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2999 - mae: 0.3044
# Epoch 39/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2036 - mae: 0.2510
# Epoch 40/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1301 - mae: 0.2312
# Epoch 41/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2031 - mae: 0.2895
# Epoch 42/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1845 - mae: 0.3073
# Epoch 43/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1851 - mae: 0.2701
# Epoch 44/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2370 - mae: 0.2836
# Epoch 45/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3528 - mae: 0.3474
# Epoch 46/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1821 - mae: 0.2695
# Epoch 47/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1435 - mae: 0.2657
# Epoch 48/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5652 - mae: 0.4110
# Epoch 49/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2746 - mae: 0.3341
# Epoch 50/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1475 - mae: 0.2573
# Epoch 51/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1597 - mae: 0.2656
# Epoch 52/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3533 - mae: 0.3392
# Epoch 53/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3290 - mae: 0.3710
# Epoch 54/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2369 - mae: 0.2926
# Epoch 55/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5001 - mae: 0.3897
# Epoch 56/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1716 - mae: 0.2723
# Epoch 57/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2057 - mae: 0.2569
# Epoch 58/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1971 - mae: 0.2926
# Epoch 59/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1850 - mae: 0.2686
# Epoch 60/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2414 - mae: 0.3142
# Epoch 61/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1919 - mae: 0.2753
# Epoch 62/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1429 - mae: 0.2255
# Epoch 63/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1137 - mae: 0.2288
# Epoch 64/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2046 - mae: 0.3374
# Epoch 65/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2220 - mae: 0.2963
# Epoch 66/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1550 - mae: 0.3097
# Epoch 67/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.0965 - mae: 0.2062
# Epoch 68/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2263 - mae: 0.2870
# Epoch 69/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1656 - mae: 0.2416
# Epoch 70/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1521 - mae: 0.2610
# Epoch 71/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1213 - mae: 0.2305
# Epoch 72/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2778 - mae: 0.3062
# Epoch 73/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3293 - mae: 0.3054
# Epoch 74/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1212 - mae: 0.2310
# Epoch 75/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1922 - mae: 0.2879
# Epoch 76/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1622 - mae: 0.2797
# Epoch 77/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2169 - mae: 0.2931
# Epoch 78/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1727 - mae: 0.2356
# Epoch 79/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2762 - mae: 0.3093
# Epoch 80/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4746 - mae: 0.4148
# Epoch 81/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1668 - mae: 0.2708
# Epoch 82/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1692 - mae: 0.2620
# Epoch 83/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4078 - mae: 0.3796
# Epoch 84/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1560 - mae: 0.2767
# Epoch 85/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3327 - mae: 0.3082
# Epoch 86/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3575 - mae: 0.3420
# Epoch 87/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2622 - mae: 0.3125
# Epoch 88/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1517 - mae: 0.2529
# Epoch 89/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1544 - mae: 0.2395
# Epoch 90/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2078 - mae: 0.2887
# Epoch 91/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1315 - mae: 0.2644
# Epoch 92/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1586 - mae: 0.2575
# Epoch 93/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2037 - mae: 0.2796
# Epoch 94/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2221 - mae: 0.2949
# Epoch 95/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1756 - mae: 0.2600
# Epoch 96/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3722 - mae: 0.3075
# Epoch 97/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1657 - mae: 0.2192
# Epoch 98/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2238 - mae: 0.3004
# Epoch 99/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2822 - mae: 0.3382
# Epoch 100/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3021 - mae: 0.3366
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bed2b950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3253 - mae: 0.3444
# processing fold # 3
# Epoch 1/100
# 118/118 [==============================] - 1s 1ms/step - loss: 1.0673 - mae: 0.7511
# Epoch 2/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7061 - mae: 0.5837
# Epoch 3/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7275 - mae: 0.5541
# Epoch 4/100
# 118/118 [==============================] - 0s 1ms/step - loss: 1.0155 - mae: 0.6196
# Epoch 5/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.8042 - mae: 0.6394
# Epoch 6/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4556 - mae: 0.4792
# Epoch 7/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5110 - mae: 0.4775
# Epoch 8/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7273 - mae: 0.5457
# Epoch 9/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5556 - mae: 0.5005
# Epoch 10/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7054 - mae: 0.5650
# Epoch 11/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.8836 - mae: 0.5625
# Epoch 12/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3446 - mae: 0.4181
# Epoch 13/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.9002 - mae: 0.5949
# Epoch 14/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5014 - mae: 0.4871
# Epoch 15/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2358 - mae: 0.3520
# Epoch 16/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3608 - mae: 0.4095
# Epoch 17/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3107 - mae: 0.4188
# Epoch 18/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3059 - mae: 0.3700
# Epoch 19/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3023 - mae: 0.3503
# Epoch 20/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4221 - mae: 0.4223
# Epoch 21/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3482 - mae: 0.3897
# Epoch 22/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3394 - mae: 0.3894
# Epoch 23/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4985 - mae: 0.4535
# Epoch 24/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4283 - mae: 0.4741
# Epoch 25/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3359 - mae: 0.3513
# Epoch 26/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5896 - mae: 0.4980
# Epoch 27/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7613 - mae: 0.5509
# Epoch 28/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5274 - mae: 0.4226
# Epoch 29/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2643 - mae: 0.3503
# Epoch 30/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4607 - mae: 0.4302
# Epoch 31/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5768 - mae: 0.4789
# Epoch 32/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3477 - mae: 0.3763
# Epoch 33/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.6250 - mae: 0.3935
# Epoch 34/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3312 - mae: 0.3920
# Epoch 35/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.6199 - mae: 0.3988
# Epoch 36/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2670 - mae: 0.3481
# Epoch 37/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3418 - mae: 0.3623
# Epoch 38/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2888 - mae: 0.2959
# Epoch 39/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2256 - mae: 0.3280
# Epoch 40/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4182 - mae: 0.3624
# Epoch 41/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2384 - mae: 0.2989
# Epoch 42/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3922 - mae: 0.3627
# Epoch 43/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3695 - mae: 0.4119
# Epoch 44/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3545 - mae: 0.3426
# Epoch 45/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2658 - mae: 0.3386
# Epoch 46/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4184 - mae: 0.3519
# Epoch 47/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3510 - mae: 0.3509
# Epoch 48/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2140 - mae: 0.3159
# Epoch 49/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4352 - mae: 0.4563
# Epoch 50/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7227 - mae: 0.5166
# Epoch 51/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4611 - mae: 0.3952
# Epoch 52/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.7857 - mae: 0.4979
# Epoch 53/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3649 - mae: 0.3380
# Epoch 54/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2404 - mae: 0.2870
# Epoch 55/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2614 - mae: 0.3651
# Epoch 56/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3137 - mae: 0.3427
# Epoch 57/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3809 - mae: 0.3514
# Epoch 58/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3054 - mae: 0.3203
# Epoch 59/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2891 - mae: 0.3399
# Epoch 60/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4679 - mae: 0.4100
# Epoch 61/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1662 - mae: 0.2501
# Epoch 62/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.2681 - mae: 0.3551
# Epoch 63/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4626 - mae: 0.3936
# Epoch 64/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2221 - mae: 0.2793
# Epoch 65/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2747 - mae: 0.3066
# Epoch 66/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.3345 - mae: 0.3563
# Epoch 67/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2434 - mae: 0.3303
# Epoch 68/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2877 - mae: 0.3496
# Epoch 69/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2548 - mae: 0.2948
# Epoch 70/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2460 - mae: 0.3528
# Epoch 71/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4148 - mae: 0.3889
# Epoch 72/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2808 - mae: 0.3035
# Epoch 73/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1839 - mae: 0.2500
# Epoch 74/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3837 - mae: 0.3925
# Epoch 75/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1756 - mae: 0.2934
# Epoch 76/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.5456 - mae: 0.4511
# Epoch 77/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2290 - mae: 0.2636
# Epoch 78/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1972 - mae: 0.2644
# Epoch 79/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2932 - mae: 0.3018
# Epoch 80/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2489 - mae: 0.3335
# Epoch 81/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2870 - mae: 0.3343
# Epoch 82/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4803 - mae: 0.4232
# Epoch 83/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3076 - mae: 0.3444
# Epoch 84/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2001 - mae: 0.2794
# Epoch 85/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2007 - mae: 0.2884
# Epoch 86/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.4158 - mae: 0.3762
# Epoch 87/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1399 - mae: 0.2636
# Epoch 88/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1950 - mae: 0.3230
# Epoch 89/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2121 - mae: 0.2967
# Epoch 90/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2918 - mae: 0.3573
# Epoch 91/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3734 - mae: 0.3682
# Epoch 92/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.2361 - mae: 0.2795
# Epoch 93/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1510 - mae: 0.2999
# Epoch 94/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.1643 - mae: 0.2936
# Epoch 95/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3452 - mae: 0.3535
# Epoch 96/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3342 - mae: 0.3565
# Epoch 97/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3794 - mae: 0.3932
# Epoch 98/100
# 118/118 [==============================] - 0s 2ms/step - loss: 0.6757 - mae: 0.4498
# Epoch 99/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3160 - mae: 0.3164
# Epoch 100/100
# 118/118 [==============================] - 0s 1ms/step - loss: 0.3819 - mae: 0.3662
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bed2bcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2019 - mae: 0.3799

# %% [markdown]
# Having all scores of different models

# %%
all_scores_relu
# Out:
# [0.38478654623031616,
#  0.3062979280948639,
#  0.3541865646839142,
#  0.3357144296169281]

# %%
all_scores_tanh
# Out:
# [0.39664533734321594,
#  0.36949414014816284,
#  0.558193027973175,
#  0.3520013988018036]

# %%
all_scores_regular
# Out:
# [0.3236422538757324,
#  0.3180753290653229,
#  0.3778620660305023,
#  0.4185025691986084]

# %%
all_scores_drop
# Out:
# [0.47142744064331055,
#  0.41873788833618164,
#  0.34443357586860657,
#  0.37986433506011963]

# %% [markdown]
# Final training of models we build

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91becb7830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1236 - mae: 0.2497

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91becb7170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1103 - mae: 0.2311

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bdb474d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1304 - mae: 0.2364

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f91bdbc9b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.1850 - mae: 0.2665

# %% [markdown]
# **Prediction part of assignment**

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 5151.000333710554
# ' the predicted Price was : [[5732.349]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 5151.000333710554
# ' the predicted Price was : [[3946.6455]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 5151.000333710554
# ' the predicted Price was : [[2843.4258]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 5151.000333710554
# ' the predicted Price was : [[5689.4023]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
